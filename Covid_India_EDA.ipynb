# %% [markdown]
# <a href="https://colab.research.google.com/github/YugantGotmare/Covid_India_EDA/blob/main/Covid_India_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip India-covid-data.zip

# %%
# Installing PySpark:
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
# Installing PySpark:
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
# Installing PySpark:
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
spark.conf.set("spark.sql.repl.eagerEval.enabled", True) # Property used to format output tables better
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://127a7dbc0e75:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('/content/Latest Covid-19 India Status.csv', inferSchema=True,
                    header=True)
df
# Out:
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |           State/UTs|Total Cases|Active|Discharged|Deaths|Active Ratio|Discharge Ratio|Death Ratio|Population|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# | Andaman and Nicobar|      10747|     0|     10618|   129|         0.0|           98.8|        1.2| 100896618|
# |      Andhra Pradesh|    2339078|     7|   2324338| 14733|         0.0|          99.37|       0.63| 128500364|
# |   Arunachal Pradesh|      66891|     0|     66595|   296|         0.0|          99.56|       0.44|    658019|
# |               Assam|     746100|     0|    738065|  8035|         0.0|          98.92|       1.08|    290492|
# |               Bihar|     851404|     1|    839100| 12303|         0.0|          98.55|       1.45|  40100376|
# |          Chandigarh|      99358|     3|     98174|  1181|         0.0|          98.81|       1.19|  30501026|
# |        Chhattisgarh|    1177768|     8|   1163614| 14146|         0.0|           98.8|        1.2|  28900667|
# |Dadra and Nagar H...|      11591|     0|     11587|     4|         0.0|          99.97|       0.03| 231502578|
# |               Delhi|    2007313|    10|   1980781| 26522|         0.0|          98.68|       1.32|    773997|
# |                 Goa|     259110|    15|    255082|  4013|        0.01|          98.45|       1.55|   3772103|
# |             Gujarat|    1277615|    11|   1266561| 11043|         0.0|          99.13|       0.86|  70400153|
# |             Haryana|    1056655|    38|   1045903| 10714|         0.0|          98.98|       1.01|   7503010|
# |    Himachal Pradesh|     312692|    14|    308465|  4213|         0.0|          98.65|       1.35|   3436948|
# |   Jammu and Kashmir|     479444|    10|    474649|  4785|         0.0|           99.0|        1.0|     66001|
# |           Jharkhand|     442574|     0|    437243|  5331|         0.0|           98.8|        1.2| 124904071|
# |           Karnataka|    4072536|   123|   4032105| 40308|         0.0|          99.01|       0.99|   1711947|
# |              Kerala|    6829249|  1300|   6756379| 71570|        0.02|          98.93|       1.05|  91702478|
# |              Ladakh|      29417|     1|     29185|   231|         0.0|          99.21|       0.79|   4184959|
# |         Lakshadweep|      11415|     0|     11363|    52|         0.0|          99.54|       0.46|  11700099|
# |      Madhya Pradesh|    1054934|     2|   1044155| 10777|         0.0|          98.98|       1.02|  14999397|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

renamed_df = df.select([F.col(col).alias(col.replace(' ', '_')) for col in df.columns])
renamed_df
# Out:
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |           State/UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# | Andaman and Nicobar|      10747|     0|     10618|   129|         0.0|           98.8|        1.2| 100896618|
# |      Andhra Pradesh|    2339078|     7|   2324338| 14733|         0.0|          99.37|       0.63| 128500364|
# |   Arunachal Pradesh|      66891|     0|     66595|   296|         0.0|          99.56|       0.44|    658019|
# |               Assam|     746100|     0|    738065|  8035|         0.0|          98.92|       1.08|    290492|
# |               Bihar|     851404|     1|    839100| 12303|         0.0|          98.55|       1.45|  40100376|
# |          Chandigarh|      99358|     3|     98174|  1181|         0.0|          98.81|       1.19|  30501026|
# |        Chhattisgarh|    1177768|     8|   1163614| 14146|         0.0|           98.8|        1.2|  28900667|
# |Dadra and Nagar H...|      11591|     0|     11587|     4|         0.0|          99.97|       0.03| 231502578|
# |               Delhi|    2007313|    10|   1980781| 26522|         0.0|          98.68|       1.32|    773997|
# |                 Goa|     259110|    15|    255082|  4013|        0.01|          98.45|       1.55|   3772103|
# |             Gujarat|    1277615|    11|   1266561| 11043|         0.0|          99.13|       0.86|  70400153|
# |             Haryana|    1056655|    38|   1045903| 10714|         0.0|          98.98|       1.01|   7503010|
# |    Himachal Pradesh|     312692|    14|    308465|  4213|         0.0|          98.65|       1.35|   3436948|
# |   Jammu and Kashmir|     479444|    10|    474649|  4785|         0.0|           99.0|        1.0|     66001|
# |           Jharkhand|     442574|     0|    437243|  5331|         0.0|           98.8|        1.2| 124904071|
# |           Karnataka|    4072536|   123|   4032105| 40308|         0.0|          99.01|       0.99|   1711947|
# |              Kerala|    6829249|  1300|   6756379| 71570|        0.02|          98.93|       1.05|  91702478|
# |              Ladakh|      29417|     1|     29185|   231|         0.0|          99.21|       0.79|   4184959|
# |         Lakshadweep|      11415|     0|     11363|    52|         0.0|          99.54|       0.46|  11700099|
# |      Madhya Pradesh|    1054934|     2|   1044155| 10777|         0.0|          98.98|       1.02|  14999397|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# only showing top 20 rows

# %%
renamed_df = renamed_df.withColumnRenamed('State/UTs', 'State_UTs')
renamed_df = renamed_df.withColumnRenamed('Active_Ratio_(%)', 'Active_Ratio')
renamed_df = renamed_df.withColumnRenamed('Discharge_Ratio_(%)', 'Discharge_Ratio')
renamed_df = renamed_df.withColumnRenamed('Death_Ratio_(%)', 'Death_Ratio')
renamed_df
# Out:
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |           State_UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# | Andaman and Nicobar|      10747|     0|     10618|   129|         0.0|           98.8|        1.2| 100896618|
# |      Andhra Pradesh|    2339078|     7|   2324338| 14733|         0.0|          99.37|       0.63| 128500364|
# |   Arunachal Pradesh|      66891|     0|     66595|   296|         0.0|          99.56|       0.44|    658019|
# |               Assam|     746100|     0|    738065|  8035|         0.0|          98.92|       1.08|    290492|
# |               Bihar|     851404|     1|    839100| 12303|         0.0|          98.55|       1.45|  40100376|
# |          Chandigarh|      99358|     3|     98174|  1181|         0.0|          98.81|       1.19|  30501026|
# |        Chhattisgarh|    1177768|     8|   1163614| 14146|         0.0|           98.8|        1.2|  28900667|
# |Dadra and Nagar H...|      11591|     0|     11587|     4|         0.0|          99.97|       0.03| 231502578|
# |               Delhi|    2007313|    10|   1980781| 26522|         0.0|          98.68|       1.32|    773997|
# |                 Goa|     259110|    15|    255082|  4013|        0.01|          98.45|       1.55|   3772103|
# |             Gujarat|    1277615|    11|   1266561| 11043|         0.0|          99.13|       0.86|  70400153|
# |             Haryana|    1056655|    38|   1045903| 10714|         0.0|          98.98|       1.01|   7503010|
# |    Himachal Pradesh|     312692|    14|    308465|  4213|         0.0|          98.65|       1.35|   3436948|
# |   Jammu and Kashmir|     479444|    10|    474649|  4785|         0.0|           99.0|        1.0|     66001|
# |           Jharkhand|     442574|     0|    437243|  5331|         0.0|           98.8|        1.2| 124904071|
# |           Karnataka|    4072536|   123|   4032105| 40308|         0.0|          99.01|       0.99|   1711947|
# |              Kerala|    6829249|  1300|   6756379| 71570|        0.02|          98.93|       1.05|  91702478|
# |              Ladakh|      29417|     1|     29185|   231|         0.0|          99.21|       0.79|   4184959|
# |         Lakshadweep|      11415|     0|     11363|    52|         0.0|          99.54|       0.46|  11700099|
# |      Madhya Pradesh|    1054934|     2|   1044155| 10777|         0.0|          98.98|       1.02|  14999397|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# only showing top 20 rows

# %%
renamed_df.createOrReplaceTempView('Data')

# %%
spark.sql('Select * from Data')
# Out:
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |           State_UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# | Andaman and Nicobar|      10747|     0|     10618|   129|         0.0|           98.8|        1.2| 100896618|
# |      Andhra Pradesh|    2339078|     7|   2324338| 14733|         0.0|          99.37|       0.63| 128500364|
# |   Arunachal Pradesh|      66891|     0|     66595|   296|         0.0|          99.56|       0.44|    658019|
# |               Assam|     746100|     0|    738065|  8035|         0.0|          98.92|       1.08|    290492|
# |               Bihar|     851404|     1|    839100| 12303|         0.0|          98.55|       1.45|  40100376|
# |          Chandigarh|      99358|     3|     98174|  1181|         0.0|          98.81|       1.19|  30501026|
# |        Chhattisgarh|    1177768|     8|   1163614| 14146|         0.0|           98.8|        1.2|  28900667|
# |Dadra and Nagar H...|      11591|     0|     11587|     4|         0.0|          99.97|       0.03| 231502578|
# |               Delhi|    2007313|    10|   1980781| 26522|         0.0|          98.68|       1.32|    773997|
# |                 Goa|     259110|    15|    255082|  4013|        0.01|          98.45|       1.55|   3772103|
# |             Gujarat|    1277615|    11|   1266561| 11043|         0.0|          99.13|       0.86|  70400153|
# |             Haryana|    1056655|    38|   1045903| 10714|         0.0|          98.98|       1.01|   7503010|
# |    Himachal Pradesh|     312692|    14|    308465|  4213|         0.0|          98.65|       1.35|   3436948|
# |   Jammu and Kashmir|     479444|    10|    474649|  4785|         0.0|           99.0|        1.0|     66001|
# |           Jharkhand|     442574|     0|    437243|  5331|         0.0|           98.8|        1.2| 124904071|
# |           Karnataka|    4072536|   123|   4032105| 40308|         0.0|          99.01|       0.99|   1711947|
# |              Kerala|    6829249|  1300|   6756379| 71570|        0.02|          98.93|       1.05|  91702478|
# |              Ladakh|      29417|     1|     29185|   231|         0.0|          99.21|       0.79|   4184959|
# |         Lakshadweep|      11415|     0|     11363|    52|         0.0|          99.54|       0.46|  11700099|
# |      Madhya Pradesh|    1054934|     2|   1044155| 10777|         0.0|          98.98|       1.02|  14999397|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# only showing top 20 rows

# %%
spark.sql('select count(State_UTs) from Data')
# Out:
# +----------------+
# |count(State_UTs)|
# +----------------+
# |              36|
# +----------------+

# %%
spark.sql('select * from Data order by Active desc limit 5')
# Out:
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |  State_UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |     Kerala|    6829249|  1300|   6756379| 71570|        0.02|          98.93|       1.05|  91702478|
# |Maharashtra|    8136945|   134|   7988392|148419|         0.0|          98.17|       1.82|    399001|
# |  Karnataka|    4072536|   123|   4032105| 40308|         0.0|          99.01|       0.99|   1711947|
# |     Odisha|    1336595|    84|   1327306|  9205|        0.01|          99.31|       0.69|  19301096|
# | Puducherry|     175636|    73|    173588|  1975|        0.04|          98.83|       1.12|   2073074|
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+

# %%
spark.sql('select * from Data order by Death_Ratio desc limit 5')
# Out:
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |  State_UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |     Punjab|     784282|    29|    764964| 19289|         0.0|          97.54|       2.46|  34698876|
# |   Nagaland|      35986|     0|     35204|   782|         0.0|          97.83|       2.17|  38157311|
# |Maharashtra|    8136945|   134|   7988392|148419|         0.0|          98.17|       1.82|    399001|
# |Uttarakhand|     449429|    11|    441665|  7753|         0.0|          98.27|       1.73|  85002417|
# |  Meghalaya|      96786|     1|     95161|  1624|         0.0|          98.32|       1.68|  79502477|
# +-----------+-----------+------+----------+------+------------+---------------+-----------+----------+

# %%
spark.sql('select sum(Total_Cases), sum(Deaths) from data')
# Out:
# +----------------+-----------+
# |sum(Total_Cases)|sum(Deaths)|
# +----------------+-----------+
# |        44681233|     530726|
# +----------------+-----------+

# %%
spark.sql('select * from Data order by Active asc limit 5')
# Out:
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |           State_UTs|Total_Cases|Active|Discharged|Deaths|Active_Ratio|Discharge_Ratio|Death_Ratio|Population|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+
# |         Lakshadweep|      11415|     0|     11363|    52|         0.0|          99.54|       0.46|  11700099|
# | Andaman and Nicobar|      10747|     0|     10618|   129|         0.0|           98.8|        1.2| 100896618|
# |Dadra and Nagar H...|      11591|     0|     11587|     4|         0.0|          99.97|       0.03| 231502578|
# |   Arunachal Pradesh|      66891|     0|     66595|   296|         0.0|          99.56|       0.44|    658019|
# |           Jharkhand|     442574|     0|    437243|  5331|         0.0|           98.8|        1.2| 124904071|
# +--------------------+-----------+------+----------+------+------------+---------------+-----------+----------+

# %%
import pandas as pd

pd_df = renamed_df.toPandas()
pd_df.head()
# Out:
#              State_UTs  Total_Cases  Active  Discharged  Deaths  Active_Ratio  \
# 0  Andaman and Nicobar        10747       0       10618     129           0.0
# 1       Andhra Pradesh      2339078       7     2324338   14733           0.0
# 2    Arunachal Pradesh        66891       0       66595     296           0.0
# 3                Assam       746100       0      738065    8035           0.0
# 4                Bihar       851404       1      839100   12303           0.0
#
#    Discharge_Ratio  Death_Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.55         1.45    40100376

# %%
pd_df.shape
# Out:
# (36, 9)

# %%
pd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State_UTs        36 non-null     object
#  1   Total_Cases      36 non-null     int32
#  2   Active           36 non-null     int32
#  3   Discharged       36 non-null     int32
#  4   Deaths           36 non-null     int32
#  5   Active_Ratio     36 non-null     float64
#  6   Discharge_Ratio  36 non-null     float64
#  7   Death_Ratio      36 non-null     float64
#  8   Population       36 non-null     int32
# dtypes: float64(3), int32(5), object(1)
# memory usage: 2.0+ KB

# %%
pd_df.describe()
# Out:
#         Total_Cases       Active    Discharged         Deaths  Active_Ratio  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000     36.000000
# mean   1.241145e+06    56.527778  1.226346e+06   14742.388889      0.002222
# std    1.834031e+06   215.847762  1.808252e+06   27170.089767      0.007601
# min    1.074700e+04     0.000000  1.061800e+04       4.000000      0.000000
# 25%    1.058650e+05     0.000000  1.048640e+05    1120.750000      0.000000
# 50%    6.127720e+05     7.500000  6.063570e+05    6542.000000      0.000000
# 75%    1.320822e+06    27.500000  1.311256e+06   14292.750000      0.000000
# max    8.136945e+06  1300.000000  7.988392e+06  148419.000000      0.040000
#
#        Discharge_Ratio  Death_Ratio    Population
# count        36.000000    36.000000  3.600000e+01
# mean         98.893333     1.103889  3.971861e+07
# std           0.498764     0.498479  5.050913e+07
# min          97.540000     0.030000  6.600100e+04
# 25%          98.672500     0.842500  1.695473e+06
# 50%          98.925000     1.070000  2.410088e+07
# 75%          99.150000     1.327500  6.979986e+07
# max          99.970000     2.460000  2.315026e+08

# %%
pd_df.isnull().sum()
# Out:
# State_UTs          0
# Total_Cases        0
# Active             0
# Discharged         0
# Deaths             0
# Active_Ratio       0
# Discharge_Ratio    0
# Death_Ratio        0
# Population         0
# dtype: int64

# %%
pd_df['State_UTs'].value_counts().sum()
# Out:
# 36

# %%
pd_df['State_UTs'].unique()
# Out:
# array(['Andaman and Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telengana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
pd_df['Deaths'].min(), pd_df['Deaths'].max()
# Out:
# (4, 148419)

# %%
pd_df[pd_df['Deaths'] == pd_df['Deaths'].min()]
# Out:
#                                   State_UTs  Total_Cases  Active  Discharged  \
# 7  Dadra and Nagar Haveli and Daman and Diu        11591       0       11587
#
#    Deaths  Active_Ratio  Discharge_Ratio  Death_Ratio  Population
# 7       4           0.0            99.97         0.03   231502578

# %%
pd_df[pd_df['Deaths'] == pd_df['Deaths'].max()]
# Out:
#       State_UTs  Total_Cases  Active  Discharged  Deaths  Active_Ratio  \
# 20  Maharashtra      8136945     134     7988392  148419           0.0
#
#     Discharge_Ratio  Death_Ratio  Population
# 20            98.17         1.82      399001

# %%
pd_df[pd_df['Total_Cases'] == pd_df['Total_Cases'].min()]
# Out:
#              State_UTs  Total_Cases  Active  Discharged  Deaths  Active_Ratio  \
# 0  Andaman and Nicobar        10747       0       10618     129           0.0
#
#    Discharge_Ratio  Death_Ratio  Population
# 0             98.8          1.2   100896618

# %%
pd_df[pd_df['Total_Cases'] == pd_df['Total_Cases'].max()]
# Out:
#       State_UTs  Total_Cases  Active  Discharged  Deaths  Active_Ratio  \
# 20  Maharashtra      8136945     134     7988392  148419           0.0
#
#     Discharge_Ratio  Death_Ratio  Population
# 20            98.17         1.82      399001

# %%
pd_df[['State_UTs','Deaths']].sort_values(by='Deaths',ascending=False)[:10]
# Out:
#          State_UTs  Deaths
# 20     Maharashtra  148419
# 16          Kerala   71570
# 15       Karnataka   40308
# 30      Tamil Nadu   38049
# 8            Delhi   26522
# 33   Uttar Pradesh   23634
# 35     West Bengal   21532
# 27          Punjab   19289
# 1   Andhra Pradesh   14733
# 6     Chhattisgarh   14146

# %%
pd_df[['State_UTs','Deaths']].sort_values(by='Deaths',ascending=True)[:10]
# Out:
#                                    State_UTs  Deaths
# 7   Dadra and Nagar Haveli and Daman and Diu       4
# 18                               Lakshadweep      52
# 0                        Andaman and Nicobar     129
# 17                                    Ladakh     231
# 2                          Arunachal Pradesh     296
# 29                                    Sikkim     499
# 23                                   Mizoram     726
# 24                                  Nagaland     782
# 32                                   Tripura     940
# 5                                 Chandigarh    1181

# %%
pd_df[['State_UTs','Population','Total_Cases']].sort_values(by='Population',ascending=False)
# Out:
#                                    State_UTs  Population  Total_Cases
# 7   Dadra and Nagar Haveli and Daman and Diu   231502578        11591
# 1                             Andhra Pradesh   128500364      2339078
# 14                                 Jharkhand   124904071       442574
# 0                        Andaman and Nicobar   100896618        10747
# 16                                    Kerala    91702478      6829249
# 34                               Uttarakhand    85002417       449429
# 29                                    Sikkim    83697770        44321
# 22                                 Meghalaya    79502477        96786
# 10                                   Gujarat    70400153      1277615
# 31                                 Telengana    69599762       841453
# 21                                   Manipur    47099270       139924
# 4                                      Bihar    40100376       851404
# 24                                  Nagaland    38157311        35986
# 30                                Tamil Nadu    35998752      3594573
# 27                                    Punjab    34698876       784282
# 35                               West Bengal    32199722      2118696
# 5                                 Chandigarh    30501026        99358
# 6                               Chhattisgarh    28900667      1177768
# 25                                    Odisha    19301096      1336595
# 19                            Madhya Pradesh    14999397      1054934
# 18                               Lakshadweep    11700099        11415
# 11                                   Haryana     7503010      1056655
# 17                                    Ladakh     4184959        29417
# 9                                        Goa     3772103       259110
# 12                          Himachal Pradesh     3436948       312692
# 26                                Puducherry     2073074       175636
# 15                                 Karnataka     1711947      4072536
# 32                                   Tripura     1646050       108034
# 28                                 Rajasthan     1521992      1315564
# 23                                   Mizoram     1308967       238964
# 33                             Uttar Pradesh     1158040      2128154
# 8                                      Delhi      773997      2007313
# 2                          Arunachal Pradesh      658019        66891
# 20                               Maharashtra      399001      8136945
# 3                                      Assam      290492       746100
# 13                         Jammu and Kashmir       66001       479444

# %%
pd_df.corr()
# Out:
# <ipython-input-37-b9f1acb26264>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                  Total_Cases    Active  Discharged    Deaths  Active_Ratio  \
# Total_Cases         1.000000  0.620330    0.999988  0.944666      0.123534
# Active              0.620330  1.000000    0.622134  0.460554      0.442108
# Discharged          0.999988  0.622134    1.000000  0.943053      0.124280
# Deaths              0.944666  0.460554    0.943053  1.000000      0.064079
# Active_Ratio        0.123534  0.442108    0.124280  0.064079      1.000000
# Discharge_Ratio    -0.120602 -0.007559   -0.118471 -0.256172     -0.015575
# Death_Ratio         0.116734  0.000705    0.114602  0.252610     -0.000838
# Population         -0.067061  0.132830   -0.066282 -0.116534     -0.076635
#
#                  Discharge_Ratio  Death_Ratio  Population
# Total_Cases            -0.120602     0.116734   -0.067061
# Active                 -0.007559     0.000705    0.132830
# Discharged             -0.118471     0.114602   -0.066282
# Deaths                 -0.256172     0.252610   -0.116534
# Active_Ratio           -0.015575    -0.000838   -0.076635
# Discharge_Ratio         1.000000    -0.999832    0.167662
# Death_Ratio            -0.999832     1.000000   -0.166338
# Population              0.167662    -0.166338    1.000000

# %%
pd_df[['State_UTs','Active']].sort_values(by='Active',ascending=False)[:10]
# Out:
#       State_UTs  Active
# 16       Kerala    1300
# 20  Maharashtra     134
# 15    Karnataka     123
# 25       Odisha      84
# 26   Puducherry      73
# 30   Tamil Nadu      58
# 35  West Bengal      50
# 11      Haryana      38
# 27       Punjab      29
# 31    Telengana      27

# %%
import plotly.express as px

x=pd_df[['State_UTs','Deaths']].sort_values(by='Deaths',ascending=False)['State_UTs'][:10].values

y=pd_df[['State_UTs','Deaths']].sort_values(by='Deaths',ascending=False)['Deaths'][:10].values

df=pd.DataFrame({'State_UTs':x,
                'Deaths':y})
fig=px.bar(df,
          x='State_UTs',
          y='Deaths',
          color='State_UTs',
          title='State_UTs Vs No. of Deaths')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="460c0d59-65f2-46aa-a7be-c5aeb98ef8e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("460c0d59-65f2-46aa-a7be-c5aeb98ef8e0")) {                    Plotly.newPlot(                        "460c0d59-65f2-46aa-a7be-c5aeb98ef8e0",                        [{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Maharashtra","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Maharashtra","offsetgroup":"Maharashtra","orientation":"v","showlegend":true,"textposition":"auto","x":["Maharashtra"],"xaxis":"x","y":[148419],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Kerala","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Kerala","offsetgroup":"Kerala","orientation":"v","showlegend":true,"textposition":"auto","x":["Kerala"],"xaxis":"x","y":[71570],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Karnataka","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Karnataka","offsetgroup":"Karnataka","orientation":"v","showlegend":true,"textposition":"auto","x":["Karnataka"],"xaxis":"x","y":[40308],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Tamil Nadu","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Tamil Nadu","offsetgroup":"Tamil Nadu","orientation":"v","showlegend":true,"textposition":"auto","x":["Tamil Nadu"],"xaxis":"x","y":[38049],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Delhi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","x":["Delhi"],"xaxis":"x","y":[26522],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Uttar Pradesh","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Uttar Pradesh","offsetgroup":"Uttar Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Uttar Pradesh"],"xaxis":"x","y":[23634],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"West Bengal","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"West Bengal","offsetgroup":"West Bengal","orientation":"v","showlegend":true,"textposition":"auto","x":["West Bengal"],"xaxis":"x","y":[21532],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Punjab","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Punjab","offsetgroup":"Punjab","orientation":"v","showlegend":true,"textposition":"auto","x":["Punjab"],"xaxis":"x","y":[19289],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh"],"xaxis":"x","y":[14733],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"State_UTs=%{x}<br>Deaths=%{y}<extra></extra>","legendgroup":"Chhattisgarh","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Chhattisgarh","offsetgroup":"Chhattisgarh","orientation":"v","showlegend":true,"textposition":"auto","x":["Chhattisgarh"],"xaxis":"x","y":[14146],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histog ...

# %%
# Make 4 Histograms: 'Total Cases', 'Deaths', 'Active', 'Discharged'
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

fig = make_subplots(rows=2, cols=2, subplot_titles=['Total Cases', 'Deaths', 'Active', 'Discharged'])

total_cases = go.Histogram(x=pd_df['Total_Cases'], nbinsx=20, name='Total Cases')
deaths = go.Histogram(x=pd_df['Deaths'], nbinsx=20, name='Deaths')
active = go.Histogram(x=pd_df['Active'], nbinsx=20, name='Active')
discharged = go.Histogram(x=pd_df['Discharged'], nbinsx=20, name='Discharged')

fig.add_trace(total_cases, 1, 1)
fig.add_trace(deaths, 1, 2)
fig.add_trace(active, 2, 1)
fig.add_trace(discharged, 2, 2)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="b623e5e2-f3f7-4fbd-8a61-18fb25e8e291" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b623e5e2-f3f7-4fbd-8a61-18fb25e8e291")) {                    Plotly.newPlot(                        "b623e5e2-f3f7-4fbd-8a61-18fb25e8e291",                        [{"name":"Total Cases","nbinsx":20,"x":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"type":"histogram","xaxis":"x","yaxis":"y"},{"name":"Deaths","nbinsx":20,"x":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"histogram","xaxis":"x2","yaxis":"y2"},{"name":"Active","nbinsx":20,"x":[0,7,0,0,1,3,8,0,10,15,11,38,14,10,0,123,1300,1,0,2,134,0,1,0,0,84,73,29,5,2,58,27,0,18,11,50],"type":"histogram","xaxis":"x3","yaxis":"y3"},{"name":"Discharged","nbinsx":20,"x":[10618,2324338,66595,738065,839100,98174,1163614,11587,1980781,255082,1266561,1045903,308465,474649,437243,4032105,6756379,29185,11363,1044155,7988392,137775,95161,238238,35204,1327306,173588,764964,1305906,43820,3556466,837315,107094,2104502,441665,2097114],"type":"histogram","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"] ...

# %%
fig = make_subplots(rows=2, cols=2, subplot_titles=['Total Cases', 'Deaths', 'Active', 'Discharged'])

total_cases = go.Box(x=pd_df['Total_Cases'], name='Total Cases', text=pd_df['State_UTs'])
deaths = go.Box(x=pd_df['Deaths'], name='Deaths', text=pd_df['State_UTs'])
active = go.Box(x=pd_df['Active'], name='Active', text=pd_df['State_UTs'])
discharged = go.Box(x=pd_df['Discharged'], name='Discharged', text=pd_df['State_UTs'])

fig.add_trace(total_cases, 1, 1)
fig.add_trace(deaths, 1, 2)
fig.add_trace(active, 2, 1)
fig.add_trace(discharged, 2, 2)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="4461b507-72cb-4501-8025-f6f881e49a94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4461b507-72cb-4501-8025-f6f881e49a94")) {                    Plotly.newPlot(                        "4461b507-72cb-4501-8025-f6f881e49a94",                        [{"name":"Total Cases","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"type":"box","xaxis":"x","yaxis":"y"},{"name":"Deaths","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"box","xaxis":"x2","yaxis":"y2"},{"name":"Active","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[0,7,0,0,1,3,8,0,10,15,11,38,14,10,0,123,1300,1,0,2,134,0,1,0,0,84,73,29,5,2,58,27,0,18,11,50],"type":"box","xaxis":"x3","yaxis":"y3"},{"name":"Discharged","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[10618,2324338,66595,738065,839100,98174,1163614,11587,1980781,255082,1266561,1045903,308465,474649,437243,4032105,6756379,29185,11363,1044155,7988392,137775,95161,238238,35204,1327306,173588,764964,1305906,43820,3556466,837315,107094,2104502,441665,2097114],"type":"box","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth" ...

# %%
fig = make_subplots(rows=2, cols=2, subplot_titles=['Total Cases', 'Deaths', 'Active', 'Discharged'])

total_cases = go.Bar(y=pd_df['Total_Cases'], name='Total Cases', hovertext=pd_df['State_UTs'])
deaths = go.Bar(y=pd_df['Deaths'], name='Deaths', hovertext=pd_df['State_UTs'])
active = go.Bar(y=pd_df['Active'], name='Active', hovertext=pd_df['State_UTs'])
discharged = go.Bar(y=pd_df['Discharged'], name='Discharged', hovertext=pd_df['State_UTs'])

fig.add_trace(total_cases, 1, 1)
fig.add_trace(deaths, 1, 2)
fig.add_trace(active, 2, 1)
fig.add_trace(discharged, 2, 2)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="0d00340a-2a57-40da-a698-7dc866ff8e36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d00340a-2a57-40da-a698-7dc866ff8e36")) {                    Plotly.newPlot(                        "0d00340a-2a57-40da-a698-7dc866ff8e36",                        [{"hovertext":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Total Cases","y":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"type":"bar","xaxis":"x","yaxis":"y"},{"hovertext":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Deaths","y":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"bar","xaxis":"x2","yaxis":"y2"},{"hovertext":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Active","y":[0,7,0,0,1,3,8,0,10,15,11,38,14,10,0,123,1300,1,0,2,134,0,1,0,0,84,73,29,5,2,58,27,0,18,11,50],"type":"bar","xaxis":"x3","yaxis":"y3"},{"hovertext":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Discharged","y":[10618,2324338,66595,738065,839100,98174,1163614,11587,1980781,255082,1266561,1045903,308465,474649,437243,4032105,6756379,29185,11363,1044155,7988392,137775,95161,238238,35204,1327306,173588,764964,1305906,43820,3556466,837315,107094,2104502,441665,2097114],"type":"bar","xaxis":"x4","yaxis":"y4"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f9 ...

# %%
import plotly.graph_objects as go
import plotly.offline as offline

fig = go.Figure([
    go.Bar(
        y=pd_df['Total_Cases'],
        name='Total Cases',
        hovertext=pd_df['State_UTs'],
        x=pd_df['State_UTs']
    ),
    go.Bar(
        y=pd_df['Discharged'],
        name='Discharged',
        hovertext=pd_df['State_UTs'],
        x=pd_df['State_UTs']
    )
])

fig.update_layout(barmode='group')
fig.update_layout(title='Total & Discharged Cases')

# Save the figure as an HTML file
offline.plot(fig, filename='my_figure.html')
# Out:
# 'my_figure.html'

# %%
fig = make_subplots(rows=2, cols=2,
                    subplot_titles=['Total Cases', 'Deaths', 'Active', 'Discharged'],
                    specs=[[{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}]])

total_cases = go.Pie(values=pd_df['Total_Cases'], name='Total Cases', labels=pd_df['State_UTs'])
deaths = go.Pie(values=pd_df['Deaths'], name='Deaths', labels=pd_df['State_UTs'])
active = go.Pie(values=pd_df['Active'], name='Active', labels=pd_df['State_UTs'])
discharged = go.Pie(values=pd_df['Discharged'], name='Discharged', labels=pd_df['State_UTs'])

fig.add_trace(total_cases, 1, 1)
fig.add_trace(deaths, 1, 2)
fig.add_trace(active, 2, 1)
fig.add_trace(discharged, 2, 2)

fig.update_traces(hoverinfo='percent+label')
fig.update_layout(showlegend=False)

fig.update_traces(textposition='inside')

fig = go.Figure(fig)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5a7cfcfd-4edf-4560-9534-21b17cfc6dd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5a7cfcfd-4edf-4560-9534-21b17cfc6dd9")) {                    Plotly.newPlot(                        "5a7cfcfd-4edf-4560-9534-21b17cfc6dd9",                        [{"domain":{"x":[0.0,0.45],"y":[0.625,1.0]},"hoverinfo":"percent+label","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Total Cases","textposition":"inside","values":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"type":"pie"},{"domain":{"x":[0.55,1.0],"y":[0.625,1.0]},"hoverinfo":"percent+label","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Deaths","textposition":"inside","values":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"pie"},{"domain":{"x":[0.0,0.45],"y":[0.0,0.375]},"hoverinfo":"percent+label","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Active","textposition":"inside","values":[0,7,0,0,1,3,8,0,10,15,11,38,14,10,0,123,1300,1,0,2,134,0,1,0,0,84,73,29,5,2,58,27,0,18,11,50],"type":"pie"},{"domain":{"x":[0.55,1.0],"y":[0.0,0.375]},"hoverinfo":"percent+label","labels":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"name":"Discharged","textposition":"inside","values":[10618,2324338,66595,738065,839100,98174,1163614,11587,1980781,255082,1266561,1045903,308465,474649,437243,4032105,6756379,29185,11363,1044155,7988392,137775,95161,238238,35204,1327306,173588,764964,1305906,43820,3556466,837315,107094,2104502,441665,2097114],"type":"pie"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Total Cases","x":0.225,"xanchor":"center","xref":"paper"," ...

# %%
fig = go.Figure([go.Scatter(x=pd_df['Total_Cases'], y=pd_df['Deaths'], mode='markers', text=pd_df['State_UTs'])])
fig.update_layout(title='Deaths vs Total Cases', xaxis_title='Total Cases', yaxis_title='Deaths')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7eb937e1-7490-419d-8cda-c57e9ab9b556" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eb937e1-7490-419d-8cda-c57e9ab9b556")) {                    Plotly.newPlot(                        "7eb937e1-7490-419d-8cda-c57e9ab9b556",                        [{"mode":"markers","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"y":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","col ...

# %%
X = pd_df['Total_Cases'].to_numpy()
y = pd_df['Deaths'].to_numpy()

X.shape, y.shape
# Out:
# ((36,), (36,))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X.reshape((len(X), 1)), y)
(model.intercept_, model.coef_[0])
# Out:
# (-2627.0314759071643, 0.013994670494716607)

# %%
model.score(X.reshape((len(X), 1)), y)
# Out:
# 0.8923936047848567

# %%
predictions = model.predict(X.reshape((len(X), 1)))
predictions.shape
# Out:
# (36,)

# %%
fig = go.Figure([go.Scatter(x=pd_df['Total_Cases'], y=pd_df['Deaths'], mode='markers', text=pd_df['State_UTs'], name='Actual Deaths'),
                 go.Scatter(x=pd_df['Total_Cases'], y=predictions, name='Predicted Deaths')])
fig.update_layout(title='Deaths vs Total Cases', xaxis_title='Total Cases', yaxis_title='Deaths')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7c3454b1-afc9-45e0-8be1-7bbd921c116f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c3454b1-afc9-45e0-8be1-7bbd921c116f")) {                    Plotly.newPlot(                        "7c3454b1-afc9-45e0-8be1-7bbd921c116f",                        [{"mode":"markers","name":"Actual Deaths","text":["Andaman and Nicobar","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chhattisgarh","Dadra and Nagar Haveli and Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Ladakh","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal"],"x":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"y":[129,14733,296,8035,12303,1181,14146,4,26522,4013,11043,10714,4213,4785,5331,40308,71570,231,52,10777,148419,2149,1624,726,782,9205,1975,19289,9653,499,38049,4111,940,23634,7753,21532],"type":"scatter"},{"name":"Predicted Deaths","x":[10747,2339078,66891,746100,851404,99358,1177768,11591,2007313,259110,1277615,1056655,312692,479444,442574,4072536,6829249,29417,11415,1054934,8136945,139924,96786,238964,35986,1336595,175636,784282,1315564,44321,3594573,841453,108034,2128154,449429,2118696],"y":[-2476.630752100445,30107.594395533568,-1690.9139718450758,7814.392180200895,9288.086961976534,-1236.5490048931117,13855.443603314225,-2464.819250202904,25464.65253885391,999.1275959788559,15252.769468200195,12160.507075687612,1748.9900304267612,4082.629324761744,3566.645823621543,54366.76792196403,92946.05800546573,-2215.350253964086,-2467.2823122099744,12136.422247766204,111246.83263272466,-668.8412016044379,-1272.543297405523,717.1909641922948,-2123.4192634842925,16078.175133978579,-169.06352889711843,8348.736689030166,15783.853218804195,-2006.7736849108296,47677.83322829779,9148.825995883608,-1115.1312436809505,27155.78251610596,3662.579289862826,27023.420922566933],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.444444 ...
